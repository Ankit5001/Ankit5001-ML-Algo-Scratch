# %% [markdown]
# ## What is simple Linear Regression ?
#     Definition: Simple linear regression is a statistical method used to model the relationship between a dependent variable (target) and a single independent variable (predictor). The goal is to find the best-fitting straight line (regression line) that predicts the dependent variable based on the independent variable.

# %% [markdown]
# ### Import  Required Library

# %%
from sklearn.datasets import make_regression
import numpy as np
import matplotlib.pyplot as plt

# %%
# create dummy data
seed = np.random.seed(42)
X,y = make_regression(n_samples=100 , n_features= 1 , n_informative=1 ,n_targets=1 ,noise=5)
plt.scatter(X,y)
plt.show()

# %% [markdown]
# ## Creating 2D  Linear class from  Scratch

# %% [markdown]
# <img src="../images/mse.png" alt="Drawing" style="width: 500px;" title="Mean Squared Error"/>

# %%
class SimpleLR:
    def __init__(self):
        self.b = None
        self.m = None

    def fit(self,X,y ):
        x_mean = np.mean(X)
        y_mean = np.mean(y)
        m_num = 0
        m_den = 0

        for i in range(X.shape[0]):
            m_num += (y[i]-y_mean)*(X[i]-x_mean)
            m_den += (X[i] - x_mean)**2

        self.m = m_num / m_den
        self.b = y_mean - self.m*x_mean
   
    def predict(self , x_test):
        return self.m*x_test + self.b

# %%
# Check coefficient and intercepts from scikit learn library

from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X,y)
print(lr.coef_ ,lr.intercept_)
# Out:
# [43.08913515] 0.5825576602634861

# %%
# Check coefficient and intercepts from our code

lr = SimpleLR()
lr.fit(X,y)

# %% [markdown]
# #### Creating  Best fit line

# %%
x = np.linspace(-3 , 3 ,50)
y_p = lr.predict(x)

plt.scatter(X,y)
plt.plot(x , y_p,color='red')
plt.show()

# %% [markdown]
# ### ***************************************** THE END *******************************************
