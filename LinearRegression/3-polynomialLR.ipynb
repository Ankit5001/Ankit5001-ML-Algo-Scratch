# %% [markdown]
# # What is Polynomial Regression?

# %% [markdown]
# Polynomial regression is a type of regression analysis where the relationship between the independent variable ( x ) and the dependent variable ( y ) is modeled as an ( n )-th degree polynomial. Unlike simple linear regression, which assumes a linear relationship between the variables, polynomial regression can capture more complex, nonlinear relationships.

# %% [markdown]
# ## Mathematical Formulation
#  The polynomial regression model can be expressed as:
#  y=β0​+β1​x+β2​x2+β3​x3+…+βh​xh+ϵ

# %% [markdown]
# ##### SCIKIT-LEARN IMPLEMENTATION

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Generate random data
np.random.seed(42)
X = np.random.rand(100, 1) * 10
y = 2.5 * X**2 - 1.5 * X + np.random.randn(100, 1) * 5

# Transform the data to include polynomial features
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

# Fit the polynomial regression model
model = LinearRegression()
model.fit(X_poly, y)
y_pred = model.predict(X_poly)

# Sort the data points for plotting
sorted_indices = np.argsort(X, axis=0).flatten()
X_sorted = X[sorted_indices]
y_pred_sorted = y_pred[sorted_indices]

# Evaluate the model
mse = mean_squared_error(y, y_pred)
r2 = r2_score(y, y_pred)

print(f'Mean Squared Error: {mse}')
print(f'R^2 Score: {r2}')

# Plot the results
plt.scatter(X, y, color='blue', label='Data')
plt.plot(X_sorted, y_pred_sorted, color='red', label='Polynomial Regression')
plt.title('Polynomial Regression')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# Mean Squared Error: 19.429841658755937
# R^2 Score: 0.9960094997963524

# %% [markdown]
# ### Polynomial class from sractch

# %%
class Polynomial:
    def __init__(self , degree = 2):
        self.degree = degree

    def fit_transform(self , data):
        ones = np.ones_like(data)
        data1 = np.hstack((ones ,data))

        for i in range(2,self.degree+1):
            data = np.hstack((data1 , data**i))

        return data

# %%
X[0:5]
# Out:
# array([[3.74540119],
#        [9.50714306],
#        [7.31993942],
#        [5.98658484],
#        [1.5601864 ]])

# %%
trf = Polynomial(2)

trf.fit_transform(X)[0]
# Out:
# array([ 1.        ,  3.74540119, 14.02803006])

# %%
X_poly[0]
# Out:
# array([ 1.        ,  3.74540119, 14.02803006])

# %% [markdown]
# #### NOTE:-  This is called linear regression because its coefficient is linear.
